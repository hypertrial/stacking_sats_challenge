# %% [markdown]
# # Tutorial 5: Stacking Sats Challenge
#
# ### Strategy Submission Template
#
# **Hosted on [Hypertrial.ai](https://www.hypertrial.ai/)**
#
# ---
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hypertrial/stacking_sats_challenge/blob/main/tutorials/5.%20Strategy%20Submission%20Template.ipynb)
#
# [![YouTube](https://img.shields.io/badge/Watch%20on-YouTube-red?logo=youtube&logoColor=white)](https://youtu.be/Lfp_n5OS6z0?si=NrLbY_NUnyQupOAO)
#
# Welcome to the submission template for the Stacking Sats Challenge.
#
# This notebook replicates the structure used by the evaluation engine to test all participant strategies. If your strategy passed all the tests in [Tutorial 4 Strategy Development Template](https://github.com/hypertrial/stacking_sats_challenge/blob/main/tutorials/4.%20Strategy%20Development%20Template.ipynb), it could still fail the tests here due to enviroment differences. Which is why we strongly encourage participants to use a virtual enviroment while developing and testing their strategies (complete [Tutorial 3. Virtual Env Setup](https://github.com/hypertrial/stacking_sats_challenge/blob/main/tutorials/3.%20Virtual%20Env%20Setup.ipynb) if you haven't already).
#
# ---
#
# ## 🛠️ What You’re Expected to Do
#
# - Paste your strategy code in the multi-line string named `model_code` in cell 3
# - Run the entire notebook and get "✅ Strategy is ready for submission."
# - Submit the exact same strategy code function for evaluation on [Hypertrial.ai](https://www.hypertrial.ai/)
#
# ---
#
# > ⚠️ Do not change function names, decorators, or global config values unless explicitly allowed.
# > Your entry must adhere to this template to be considered valid.

# %%
# !pip install --upgrade --force-reinstall hypertrial
# Out:
# Collecting hypertrial
#   Using cached hypertrial-0.1.14-py3-none-any.whl.metadata (5.5 kB)
# Collecting pandas>=1.3.0 (from hypertrial)
#   Using cached pandas-2.2.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (89 kB)
# Collecting numpy>=1.20.0 (from hypertrial)
#   Using cached numpy-2.2.5-cp310-cp310-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting matplotlib>=3.4.0 (from hypertrial)
#   Using cached matplotlib-3.10.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting coinmetrics-api-client>=2024.2.6.16 (from hypertrial)
#   Using cached coinmetrics_api_client-2025.5.6.13-py3-none-any.whl.metadata (3.4 kB)
# Collecting pytest>=6.2.0 (from hypertrial)
#   Using cached pytest-8.3.5-py3-none-any.whl.metadata (7.6 kB)
# Collecting pandas_datareader>=0.10.0 (from hypertrial)
#   Using cached pandas_datareader-0.10.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting scipy>=1.6.0 (from hypertrial)
#   Using cached scipy-1.15.2-cp310-cp310-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting psutil>=5.8.0 (from hypertrial)
#   Using cached psutil-7.0.0-cp36-abi3-macosx_11_0_arm64.whl.metadata (22 kB)
# Collecting bandit>=1.7.0 (from hypertrial)
#   Using cached bandit-1.8.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting safety>=2.0.0 (from hypertrial)
#   Using cached safety-3.4.0-py3-none-any.whl.metadata (11 kB)
# Collecting pylint>=3.0.0 (from hypertrial)
#   Using cached pylint-3.3.7-py3-none-any.whl.metadata (12 kB)
# Collecting pytest-cov>=6.0.0 (from hypertrial)
#   Using cached pytest_cov-6.1.1-py3-none-any.whl.metadata (28 kB)
# Collecting PyYAML>=5.3.1 (from bandit>=1.7.0->hypertrial)
#   Using cached PyYAML-6.0.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting stevedore>=1.20.0 (from bandit>=1.7.0->hypertrial)
#   Using cached stevedore-5.4.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting rich (from bandit>=1.7.0->hypertrial)
#   Using cached rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting orjson<4.0.0,>=3.6.0 (from coinmetrics-api-client>=2024.2.6.16->hypertrial)
#   Using cached orjson-3.10.18-cp310-cp310-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (41 kB)
# Collecting polars<2.0.0,>=1.0.0 (from coinmetrics-api-client>=2024.2.6.16->hypertrial)
#   Using cached polars-1.29.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (14 kB)
# Collecting python-dateutil<3.0.0,>=2.8.2 (from coinmetrics-api-client>=2024.2.6.16->hypertrial)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting requests<3.0.0,>=2.24.0 (from coinmetrics-api-client>=2024.2.6.16->hypertrial)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tqdm<5.0.0,>=4.64.1 (from coinmetrics-api-client>=2024.2.6.16->hypertrial)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting typer>=0.7.0 (from coinmetrics-api-client>=2024.2.6.16->hypertrial)
#   Using cached typer-0.15.3-py3-none-any.whl.metadata (15 kB)
# Collecting websocket-client<2.0.0,>=1.6.0 (from coinmetrics-api-client>=2024.2.6.16->hypertrial)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting pytz>=2020.1 (from pandas>=1.3.0->hypertrial)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.3.0->hypertrial)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil<3.0.0,>=2.8.2->coinmetrics-api-client>=2024.2.6.16->hypertrial)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3.0.0,>=2.24.0->coinmetrics-api-client>=2024.2.6.16->hypertrial)
#   Using cached charset_normalizer-3.4.2-cp310-cp310-macosx_10_9_universal2.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.24.0->coinmetrics-api-client>=2024.2.6.16->hypertrial)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.24.0->coinmetrics-api-client>=2024.2.6.16->hypertrial)
#   Using cached urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.24.0->coinmetrics-api-client>=2024.2.6.16->hypertrial)
#   Using cached certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.4.0->hypertrial)
#   Using cached contourpy-1.3.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.4.0->hypertrial)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.4.0->hypertrial)
#   Using cached fonttools-4.57.0-cp310-cp310-macosx_10_9_universal2.whl.metadata (102 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.4.0->hypertrial)
#   Using cached kiwisolver-1.4.8-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.2 kB)
# Collecting packaging>=20.0 (from matplotlib>=3.4.0->hypertrial)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pillow>=8 (from matplotlib>=3.4.0->hypertrial)
#   Using cached pillow-11.2.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (8.9 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.4.0->hypertrial)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting lxml (from pandas_datareader>=0.10.0->hypertrial)
#   Using cached lxml-5.4.0-cp310-cp310-macosx_10_9_universal2.whl.metadata (3.5 kB)
# Collecting astroid<=3.4.0.dev0,>=3.3.8 (from pylint>=3.0.0->hypertrial)
#   Using cached astroid-3.3.9-py3-none-any.whl.metadata (4.5 kB)
# Collecting dill>=0.2 (from pylint>=3.0.0->hypertrial)
#   Using cached dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting isort!=5.13,<7,>=4.2.5 (from pylint>=3.0.0->hypertrial)
#   Using cached isort-6.0.1-py3-none-any.whl.metadata (11 kB)
# Collecting mccabe<0.8,>=0.6 (from pylint>=3.0.0->hypertrial)
#   Using cached mccabe-0.7.0-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting platformdirs>=2.2 (from pylint>=3.0.0->hypertrial)
#   Using cached platformdirs-4.3.7-py3-none-any.whl.metadata (11 kB)
# Collecting tomli>=1.1 (from pylint>=3.0.0->hypertrial)
#   Using cached tomli-2.2.1-py3-none-any.whl.metadata (10 kB)
# Collecting tomlkit>=0.10.1 (from pylint>=3.0.0->hypertrial)
#   Using cached tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting typing-extensions>=4.0.0 (from astroid<=3.4.0.dev0,>=3.3.8->pylint>=3.0.0->hypertrial)
#   Using cached typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting exceptiongroup>=1.0.0rc8 (from pytest>=6.2.0->hypertrial)
#   Using cached exceptiongroup-1.2.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting iniconfig (from pytest>=6.2.0->hypertrial)
#   Using cached iniconfig-2.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pluggy<2,>=1.5 (from pytest>=6.2.0->hypertrial)
#   Using cached pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting coverage>=7.5 (from coverage[toml]>=7.5->pytest-cov>=6.0.0->hypertrial)
#   Using cached coverage-7.8.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (8.5 kB)
# Collecting authlib>=1.2.0 (from safety>=2.0.0->hypertrial)
#   Using cached authlib-1.5.2-py2.py3-none-any.whl.metadata (3.9 kB)
# Collecting click>=8.0.2 (from safety>=2.0.0->hypertrial)
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting dparse>=0.6.4 (from safety>=2.0.0->hypertrial)
#   Using cached dparse-0.6.4-py3-none-any.whl.metadata (5.5 kB)
# Collecting filelock~=3.16.1 (from safety>=2.0.0->hypertrial)
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting httpx (from safety>=2.0.0->hypertrial)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jinja2>=3.1.0 (from safety>=2.0.0->hypertrial)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting marshmallow>=3.15.0 (from safety>=2.0.0->hypertrial)
#   Using cached marshmallow-4.0.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting nltk>=3.9 (from safety>=2.0.0->hypertrial)
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting psutil>=5.8.0 (from hypertrial)
#   Using cached psutil-6.1.1-cp36-abi3-macosx_11_0_arm64.whl.metadata (22 kB)
# Collecting pydantic<2.10.0,>=2.6.0 (from safety>=2.0.0->hypertrial)
#   Using cached pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Collecting ruamel-yaml>=0.17.21 (from safety>=2.0.0->hypertrial)
#   Using cached ruamel.yaml-0.18.10-py3-none-any.whl.metadata (23 kB)
# Collecting safety-schemas==0.0.14 (from safety>=2.0.0->hypertrial)
#   Using cached safety_schemas-0.0.14-py3-none-any.whl.metadata (1.1 kB)
# Collecting setuptools>=65.5.1 (from safety>=2.0.0->hypertrial)
#   Using cached setuptools-80.3.1-py3-none-any.whl.metadata (6.5 kB)
# Collecting tenacity (from safety>=2.0.0->hypertrial)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<2.10.0,>=2.6.0->safety>=2.0.0->hypertrial)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.23.4 (from pydantic<2.10.0,>=2.6.0->safety>=2.0.0->hypertrial)
#   Using cached pydantic_core-2.23.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting cryptography (from authlib>=1.2.0->safety>=2.0.0->hypertrial)
#   Using cached cryptography-44.0.3-cp39-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Collecting MarkupSafe>=2.0 (from jinja2>=3.1.0->safety>=2.0.0->hypertrial)
#   Using cached MarkupSafe-3.0.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Collecting backports-datetime-fromisoformat (from marshmallow>=3.15.0->safety>=2.0.0->hypertrial)
#   Using cached backports_datetime_fromisoformat-2.0.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Collecting joblib (from nltk>=3.9->safety>=2.0.0->hypertrial)
#   Using cached joblib-1.5.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting regex>=2021.8.3 (from nltk>=3.9->safety>=2.0.0->hypertrial)
#   Using cached regex-2024.11.6-cp310-cp310-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel-yaml>=0.17.21->safety>=2.0.0->hypertrial)
#   Using cached ruamel.yaml.clib-0.2.12-cp310-cp310-macosx_13_0_arm64.whl.metadata (1.2 kB)
# Collecting pbr>=2.0.0 (from stevedore>=1.20.0->bandit>=1.7.0->hypertrial)
#   Using cached pbr-6.1.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.7.0->coinmetrics-api-client>=2024.2.6.16->hypertrial)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->bandit>=1.7.0->hypertrial)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich->bandit>=1.7.0->hypertrial)
#   Using cached pygments-2.19.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->bandit>=1.7.0->hypertrial)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting cffi>=1.12 (from cryptography->authlib>=1.2.0->safety>=2.0.0->hypertrial)
#   Using cached cffi-1.17.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.12->cryptography->authlib>=1.2.0->safety>=2.0.0->hypertrial)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting anyio (from httpx->safety>=2.0.0->hypertrial)
#   Using cached anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting httpcore==1.* (from httpx->safety>=2.0.0->hypertrial)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx->safety>=2.0.0->hypertrial)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting sniffio>=1.1 (from anyio->httpx->safety>=2.0.0->hypertrial)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Using cached hypertrial-0.1.14-py3-none-any.whl (246 kB)
# Using cached bandit-1.8.3-py3-none-any.whl (129 kB)
# Using cached coinmetrics_api_client-2025.5.6.13-py3-none-any.whl (51 kB)
# Using cached numpy-2.2.5-cp310-cp310-macosx_14_0_arm64.whl (5.4 MB)
# Using cached orjson-3.10.18-cp310-cp310-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (248 kB)
# Using cached pandas-2.2.3-cp310-cp310-macosx_11_0_arm64.whl (11.3 MB)
# Using cached polars-1.29.0-cp39-abi3-macosx_11_0_arm64.whl (31.1 MB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.2-cp310-cp310-macosx_10_9_universal2.whl (201 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached certifi-2025.4.26-py3-none-any.whl (159 kB)
# Using cached matplotlib-3.10.1-cp310-cp310-macosx_11_0_arm64.whl (8.0 MB)
# Using cached contourpy-1.3.2-cp310-cp310-macosx_11_0_arm64.whl (253 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.57.0-cp310-cp310-macosx_10_9_universal2.whl (2.8 MB)
# Using cached kiwisolver-1.4.8-cp310-cp310-macosx_11_0_arm64.whl (65 kB)
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Using cached pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Using cached pillow-11.2.1-cp310-cp310-macosx_11_0_arm64.whl (3.0 MB)
# Using cached pylint-3.3.7-py3-none-any.whl (522 kB)
# Using cached astroid-3.3.9-py3-none-any.whl (275 kB)
# Using cached isort-6.0.1-py3-none-any.whl (94 kB)
# Using cached mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Using cached dill-0.4.0-py3-none-any.whl (119 kB)
# Using cached platformdirs-4.3.7-py3-none-any.whl (18 kB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Using cached pytest-8.3.5-py3-none-any.whl (343 kB)
# Using cached pluggy-1.5.0-py3-none-any.whl (20 kB)
# Using cached exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Using cached pytest_cov-6.1.1-py3-none-any.whl (23 kB)
# Using cached coverage-7.8.0-cp310-cp310-macosx_11_0_arm64.whl (211 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached PyYAML-6.0.2-cp310-cp310-macosx_11_0_arm64.whl (171 kB)
# Using cached safety-3.4.0-py3-none-any.whl (267 kB)
# Using cached safety_schemas-0.0.14-py3-none-any.whl (39 kB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Using cached psutil-6.1.1-cp36-abi3-macosx_11_0_arm64.whl (248 kB)
# Using cached pydantic-2.9.2-py3-none-any.whl (434 kB)
# Using cached pydantic_core-2.23.4-cp310-cp310-macosx_11_0_arm64.whl (1.8 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached authlib-1.5.2-py2.py3-none-any.whl (232 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Using cached dparse-0.6.4-py3-none-any.whl (11 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached MarkupSafe-3.0.2-cp310-cp310-macosx_11_0_arm64.whl (12 kB)
# Using cached marshmallow-4.0.0-py3-none-any.whl (48 kB)
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Using cached regex-2024.11.6-cp310-cp310-macosx_11_0_arm64.whl (284 kB)
# Using cached ruamel.yaml-0.18.10-py3-none-any.whl (117 kB)
# Using cached ruamel.yaml.clib-0.2.12-cp310-cp310-macosx_13_0_arm64.whl (131 kB)
# Using cached scipy-1.15.2-cp310-cp310-macosx_14_0_arm64.whl (22.4 MB)
# Using cached setuptools-80.3.1-py3-none-any.whl (1.2 MB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached stevedore-5.4.1-py3-none-any.whl (49 kB)
# Using cached pbr-6.1.1-py2.py3-none-any.whl (108 kB)
# Using cached tomli-2.2.1-py3-none-any.whl (14 kB)
# Using cached tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Using cached typer-0.15.3-py3-none-any.whl (45 kB)
# Using cached rich-14.0.0-py3-none-any.whl (243 kB)
# Using cached pygments-2.19.1-py3-none-any.whl (1.2 MB)
# Using cached typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached backports_datetime_fromisoformat-2.0.3-cp310-cp310-macosx_11_0_arm64.whl (27 kB)
# Using cached cryptography-44.0.3-cp39-abi3-macosx_10_9_universal2.whl (6.7 MB)
# Using cached cffi-1.17.1-cp310-cp310-macosx_11_0_arm64.whl (178 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached anyio-4.9.0-py3-none-any.whl (100 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached iniconfig-2.1.0-py3-none-any.whl (6.0 kB)
# Using cached joblib-1.5.0-py3-none-any.whl (307 kB)
# Using cached lxml-5.4.0-cp310-cp310-macosx_10_9_universal2.whl (8.1 MB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Installing collected packages: pytz, websocket-client, urllib3, tzdata, typing-extensions, tqdm, tomlkit, tomli, tenacity, sniffio, six, shellingham, setuptools, ruamel.yaml.clib, regex, PyYAML, pyparsing, pygments, pycparser, psutil, polars, pluggy, platformdirs, pillow, packaging, orjson, numpy, mdurl, mccabe, MarkupSafe, lxml, kiwisolver, joblib, isort, iniconfig, idna, h11, fonttools, filelock, exceptiongroup, dill, cycler, coverage, click, charset-normalizer, certifi, backports-datetime-fromisoformat, annotated-types, scipy, ruamel-yaml, requests, python-dateutil, pytest, pydantic-core, pbr, nltk, marshmallow, markdown-it-py, jinja2, httpcore, dparse, contourpy, cffi, astroid, anyio, stevedore, rich, pytest-cov, pylint, pydantic, pandas, matplotlib, httpx, cryptography, typer, safety-schemas, pandas_datareader, bandit, authlib, safety, coinmetrics-api-client, hypertrial
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.8.0
#     Uninstalling websocket-client-1.8.0:
#       Successfully uninstalled websocket-client-1.8.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.4.0
#     Uninstalling urllib3-2.4.0:
#       Successfully uninstalled urllib3-2.4.0
#   Attempting uninstall: tzdata━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/82 [urllib3]
#     Found existing installation: tzdata 2025.2━━━━━━━  2/82 [urllib3]
#     Uninstalling tzdata-2025.2:━━━━━━━━━━━━━━━━━━━━━━  2/82 [urllib3]
#       Successfully uninstalled tzdata-2025.2━━━━━━━━━  2/82 [urllib3]
#   Attempting uninstall: typing-extensions━━━━━━━━━━━━━━━━━━━━━━━━━  3/82 [tzdata]
#     Found existing installation: typing_extensions 4.13.2━━━━━  3/82 [tzdata]
#     Uninstalling typing_extensions-4.13.2:━━━━━━━━━━━━━━━━━━━━  3/82 [tzdata]
#       Successfully uninstalled typing_extensions-4.13.2━━━━━━━━━━━  4/82 [typing-extensions]
#   Attempting uninstall: tqdm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/82 [typing-extensions]
#     Found existing installation: tqdm 4.67.1━━━━━━━━━━━━━━━━━━  4/82 [typing-extensions]
#     Uninstalling tqdm-4.67.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/82 [typing-extensions]
#       Successfully uninstalled tqdm-4.67.1━━━━━━━━━━━━━━━━━━━━  4/82 [typing-extensions]
#   Attempting uninstall: tomlkit━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/82 [tqdm]tensions]
#     Found existing installation: tomlkit 0.13.2━━━━━━━━━━━━━━━  5/82 [tqdm]
#     Uninstalling tomlkit-0.13.2:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/82 [tqdm]
#       Successfully uninstalled tomlkit-0.13.2━━━━━━━━━━━━━━━━━  5/82 [tqdm]
#   Attempting uninstall: tomli━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/82 [tqdm]
#     Found existing installation: tomli 2.2.1━━━━━━━━━━━━━━━━━━  5/82 [tqdm]
#     Uninstalling tomli-2.2.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/82 [tqdm]
#       Successfully uninstalled tomli-2.2.1━━━━━━━━━━━━━━━━━━━━  5/82 [tqdm]
#   Attempting uninstall: tenacity━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/82 [tqdm]
#     Found existing installation: tenacity 9.1.2━━━━━━━━━━━━━━━  5/82 [tqdm]
#     Uninstalling tenacity-9.1.2:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/82 [tqdm]
#       Successfully uninstalled tenacity-9.1.2━━━━━━━━━━━━━━━━━  5/82 [tqdm]
#   Attempting uninstall: sniffio━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/82 [tqdm]
#     Found existing installation: sniffio 1.3.1━━━━━━━━━━━━━━━━  5/82 [tqdm]
#     Uninstalling sniffio-1.3.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/82 [tqdm]
#       Successfully uninstalled sniffio-1.3.1━━━━━━━━━━━━━━━━━━  5/82 [tqdm]
#   Attempting uninstall: six━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/82 [tqdm]
#     Found existing installation: six 1.17.0━━━━━━━━━━━━━━━━━━━  5/82 [tqdm]
#     Uninstalling six-1.17.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/82 [tqdm]
#       Successfully uninstalled six-1.17.0━━━━━━━━━━━━━━━━━━━━━━━━━ 10/82 [six]
#   Attempting uninstall: shellingham━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/82 [six]
#     Found existing installation: shellingham 1.5.4━━━━━━━━━━━━ 10/82 [six]
#     Uninstalling shellingham-1.5.4:━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/82 [six]
#       Successfully uninstalled shellingham-1.5.4━━━━━━━━━━━━━━ 10/82 [six]
#   Attempting uninstall: setuptools━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/82 [six]
#     Found existing installation: setuptools 80.3.1━━━━━━━━━━━━ 10/82 [six]
#     Uninstalling setuptools-80.3.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/82 [six]
#       Successfully uninstalled setuptools-80.3.1━━━━━━━━━━━━━━ 10/82 [six]
#   Attempting uninstall: ruamel.yaml.clib━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/82 [setuptools]
#     Found existing installation: ruamel.yaml.clib 0.2.12━━━━━━ 12/82 [setuptools]
#     Uninstalling ruamel.yaml.clib-0.2.12:━━━━━━━━━━━━━━━━━━━━━ 12/82 [setuptools]
#       Successfully uninstalled ruamel.yaml.clib-0.2.12━━━━━━━━━━━━ 13/82 [ruamel.yaml.clib]
#   Attempting uninstall: regex━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/82 [ruamel.yaml.clib]
#     Found existing installation: regex 2024.11.6━━━━━━━━━━━━━━ 13/82 [ruamel.yaml.clib]
#     Uninstalling regex-2024.11.6:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/82 [ruamel.yaml.clib]
#       Successfully uninstalled regex-2024.11.6━━━━━━━━━━━━━━━━ 13/82 [ruamel.yaml.clib]
#   Attempting uninstall: PyYAML━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/82 [ruamel.yaml.clib]
#     Found existing installation: PyYAML 6.0.2━━━━━━━━━━━━━━━━━ 13/82 [ruamel.yaml.clib]
#     Uninstalling PyYAML-6.0.2:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/82 [ruamel.yaml.clib]
#       Successfully uninstalled PyYAML-6.0.2━━━━━━━━━━━━━━━━━━━ 13/82 [ruamel.yaml.clib]
#   Attempting uninstall: pyparsing━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/82 [ruamel.yaml.clib]
#     Found existing installation: pyparsing 3.2.3━━━━━━━━━━━━━━ 13/82 [ruamel.yaml.clib]
#     Uninstalling pyparsing-3.2.3:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/82 [ruamel.yaml.clib]
#       Successfully uninstalled pyparsing-3.2.3━━━━━━━━━━━━━━━━ 13/82 [ruamel.yaml.clib]
#   Attempting uninstall: pygments0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/82 [pyparsing]ib]
#     Found existing installation: Pygments 2.19.1━━━━━━━━━━━━━━ 16/82 [pyparsing]
#     Uninstalling Pygments-2.19.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/82 [pyparsing]
#       Successfully uninstalled Pygments-2.19.1━━━━━━━━━━━━━━━━ 16/82 [pyparsing]
#   Attempting uninstall: pycparser0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/82 [pygments]
#     Found existing installation: pycparser 2.22━━━━━━━━━━━━━━━ 17/82 [pygments]
#     Uninstalling pycparser-2.22:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/82 [pygments]
#       Successfully uninstalled pycparser-2.22━━━━━━━━━━━━━━━━━ 17/82 [pygments]
#   Attempting uninstall: psutil━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18/82 [pycparser]
#     Found existing installation: psutil 6.1.1━━━━━━━━━━━━━━━━━ 18/82 [pycparser]
#     Uninstalling psutil-6.1.1:m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18/82 [pycparser]
#       Successfully uninstalled psutil-6.1.1━━━━━━━━━━━━━━━━━━━ 18/82 [pycparser]
#   Attempting uninstall: polarsm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18/82 [pycparser]
#     Found existing installation: polars 1.29.0━━━━━━━━━━━━━━━━ 18/82 [pycparser]
#     Uninstalling polars-1.29.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18/82 [pycparser]
#       Successfully uninstalled polars-1.29.0━━━━━━━━━━━━━━━━━━ 18/82 [pycparser]
#   Attempting uninstall: pluggym━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/82 [polars]
#     Found existing installation: pluggy 1.5.0━━━━━━━━━━━━━━━━━ 20/82 [polars]
#     Uninstalling pluggy-1.5.0:0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/82 [polars]
#       Successfully uninstalled pluggy-1.5.0━━━━━━━━━━━━━━━━━━━ 20/82 [polars]
#   Attempting uninstall: platformdirs━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/82 [polars]
#     Found existing installation: platformdirs 4.3.7━━━━━━━━━━━ 20/82 [polars]
#     Uninstalling platformdirs-4.3.7:━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/82 [polars]
#       Successfully uninstalled platformdirs-4.3.7━━━━━━━━━━━━━ 20/82 [polars]
#   Attempting uninstall: pillow0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/82 [polars]
#     Found existing installation: pillow 11.2.1━━━━━━━━━━━━━━━━ 20/82 [polars]
#     Uninstalling pillow-11.2.1:m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/82 [polars]
#       Successfully uninstalled pillow-11.2.1━━━━━━━━━━━━━━━━━━ 20/82 [polars]
#   Attempting uninstall: packaging━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23/82 [pillow]
#     Found existing installation: packaging 25.0━━━━━━━━━━━━━━━ 23/82 [pillow]
#     Uninstalling packaging-25.0:0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23/82 [pillow]
#       Successfully uninstalled packaging-25.0━━━━━━━━━━━━━━━━━ 23/82 [pillow]
#   Attempting uninstall: orjson━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23/82 [pillow]
#     Found existing installation: orjson 3.10.18━━━━━━━━━━━━━━━ 23/82 [pillow]
#     Uninstalling orjson-3.10.18:0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23/82 [pillow]
#       Successfully uninstalled orjson-3.10.18━━━━━━━━━━━━━━━━━ 23/82 [pillow]
#   Attempting uninstall: numpy━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23/82 [pillow]
#     Found existing installation: numpy 2.2.5━━━━━━━━━━━━━━━━━━ 23/82 [pillow]
#     Uninstalling numpy-2.2.5:━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23/82 [pillow]
#       Successfully uninstalled numpy-2.2.5━━━━━━━━━━━━━━━━━━━━ 23/82 [pillow]
#   Attempting uninstall: mdurl╸━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26/82 [numpy]
#     Found existing installation: mdurl 0.1.2━━━━━━━━━━━━━━━━━━ 26/82 [numpy]
#     Uninstalling mdurl-0.1.2:m━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26/82 [numpy]
#       Successfully uninstalled mdurl-0.1.2━━━━━━━━━━━━━━━━━━━━ 26/82 [numpy]
#   Attempting uninstall: mccabe━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26/82 [numpy]
#     Found existing installation: mccabe 0.7.0━━━━━━━━━━━━━━━━━ 26/82 [numpy]
#     Uninstalling mccabe-0.7.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26/82 [numpy]
#       Successfully uninstalled mccabe-0.7.0━━━━━━━━━━━━━━━━━━━━━━━ 28/82 [mccabe]
#   Attempting uninstall: MarkupSafe0m━━━━━━━━━━━━━━━━━━━━━━━━━━ 28/82 [mccabe]
#     Found existing installation: MarkupSafe 3.0.2━━━━━━━━━━━━━ 28/82 [mccabe]
#     Uninstalling MarkupSafe-3.0.2:0m━━━━━━━━━━━━━━━━━━━━━━━━━━ 28/82 [mccabe]
#       Successfully uninstalled MarkupSafe-3.0.2━━━━━━━━━━━━━━━ 28/82 [mccabe]
#   Attempting uninstall: lxml━━━━━━━━━━━━━━━━━━━━━━━━━━ 28/82 [mccabe]
#     Found existing installation: lxml 5.4.0━━━━━━━━━━━━━━━━━━━ 28/82 [mccabe]
#     Uninstalling lxml-5.4.0:━━━━━━━━━━━━━━━━━━━━━━━━━━ 28/82 [mccabe]
#       Successfully uninstalled lxml-5.4.0━━━━━━━━━━━━━━━━━━━━━ 28/82 [mccabe]
#   Attempting uninstall: kiwisolver0m━━━━━━━━━━━━━━━━━━━━━━━━━ 30/82 [lxml]
#     Found existing installation: kiwisolver 1.4.8━━━━━━━━━━━━━ 30/82 [lxml]
#     Uninstalling kiwisolver-1.4.8:90m━━━━━━━━━━━━━━━━━━━━━━━━━ 30/82 [lxml]
#       Successfully uninstalled kiwisolver-1.4.8━━━━━━━━━━━━━━━ 30/82 [lxml]
#   Attempting uninstall: joblib0m━━━━━━━━━━━━━━━━━━━━━━━━━ 30/82 [lxml]
#     Found existing installation: joblib 1.5.0━━━━━━━━━━━━━━━━━ 30/82 [lxml]
#     Uninstalling joblib-1.5.0:0m━━━━━━━━━━━━━━━━━━━━━━━━━ 30/82 [lxml]
#       Successfully uninstalled joblib-1.5.0━━━━━━━━━━━━━━━━━━━ 30/82 [lxml]
#   Attempting uninstall: isort━━━━━━━━━━━━━━━━━━━━━━━━━ 30/82 [lxml]
#     Found existing installation: isort 6.0.1━━━━━━━━━━━━━━━━━━ 30/82 [lxml]
#     Uninstalling isort-6.0.1:━━━━━━━━━━━━━━━━━━━━━━━━━ 30/82 [lxml]
#       Successfully uninstalled isort-6.0.1━━━━━━━━━━━━━━━━━━━━ 30/82 [lxml]
#   Attempting uninstall: iniconfig╺━━━━━━━━━━━━━━━━━━━━━━━ 33/82 [isort]
#     Found existing installation: iniconfig 2.1.0━━━━━━━━━━━━━━ 33/82 [isort]
#     Uninstalling iniconfig-2.1.0:m━━━━━━━━━━━━━━━━━━━━━━━ 33/82 [isort]
#       Successfully uninstalled iniconfig-2.1.0━━━━━━━━━━━━━━━━ 33/82 [isort]
#   Attempting uninstall: idnam╺━━━━━━━━━━━━━━━━━━━━━━━ 33/82 [isort]
#     Found existing installation: idna 3.10━━━━━━━━━━━━━━━━━━━━ 33/82 [isort]
#     Uninstalling idna-3.10:0m╺━━━━━━━━━━━━━━━━━━━━━━━ 33/82 [isort]
#       Successfully uninstalled idna-3.10━━━━━━━━━━━━━━━━━━━━━━ 33/82 [isort]
#   Attempting uninstall: h110m╺━━━━━━━━━━━━━━━━━━━━━━━ 33/82 [isort]
#     Found existing installation: h11 0.16.0━━━━━━━━━━━━━━━━━━━ 33/82 [isort]
#     Uninstalling h11-0.16.0:m╺━━━━━━━━━━━━━━━━━━━━━━━ 33/82 [isort]
#       Successfully uninstalled h11-0.16.0━━━━━━━━━━━━━━━━━━━━━ 33/82 [isort]
#   Attempting uninstall: fonttoolsm━━━━━━━━━━━━━━━━━━━━━━━ 33/82 [isort]
#     Found existing installation: fonttools 4.57.0━━━━━━━━━━━━━ 33/82 [isort]
#     Uninstalling fonttools-4.57.0:━━━━━━━━━━━━━━━━━━━━━━━ 33/82 [isort]
#       Successfully uninstalled fonttools-4.57.0━━━━━━━━━━━━━━━ 33/82 [isort]
#   Attempting uninstall: filelock90m╺━━━━━━━━━━━━━━━━━━━━━ 37/82 [fonttools]
#     Found existing installation: filelock 3.16.1━━━━━━━━━━━━━━ 37/82 [fonttools]
#     Uninstalling filelock-3.16.1:━━━━━━━━━━━━━━━━━━━━━ 37/82 [fonttools]
#       Successfully uninstalled filelock-3.16.1━━━━━━━━━━━━━━━━ 37/82 [fonttools]
#   Attempting uninstall: exceptiongroup90m━━━━━━━━━━━━━━━━━━━━━ 37/82 [fonttools]
#     Found existing installation: exceptiongroup 1.2.2━━━━━━━━━ 37/82 [fonttools]
#     Uninstalling exceptiongroup-1.2.2:90m━━━━━━━━━━━━━━━━━━━━━ 37/82 [fonttools]
#       Successfully uninstalled exceptiongroup-1.2.2━━━━━━━━━━━ 37/82 [fonttools]
#   Attempting uninstall: dill90m╺━━━━━━━━━━━━━━━━━━━━━ 37/82 [fonttools]
#     Found existing installation: dill 0.4.0━━━━━━━━━━━━━━━━━━━ 37/82 [fonttools]
#     Uninstalling dill-0.4.0:90m╺━━━━━━━━━━━━━━━━━━━━━ 37/82 [fonttools]
#       Successfully uninstalled dill-0.4.0━━━━━━━━━━━━━━━━━━━━━ 37/82 [fonttools]
#   Attempting uninstall: cyclerm╺━━━━━━━━━━━━━━━━━━━━━ 37/82 [fonttools]
#     Found existing installation: cycler 0.12.1━━━━━━━━━━━━━━━━ 37/82 [fonttools]
#     Uninstalling cycler-0.12.1:╺━━━━━━━━━━━━━━━━━━━━━ 37/82 [fonttools]
#       Successfully uninstalled cycler-0.12.1━━━━━━━━━━━━━━━━━━ 37/82 [fonttools]
#   Attempting uninstall: coverage━━━━━━━━━━━━━━━━━━━━━ 37/82 [fonttools]
#     Found existing installation: coverage 7.8.0━━━━━━━━━━━━━━━ 37/82 [fonttools]
#     Uninstalling coverage-7.8.0:━━━━━━━━━━━━━━━━━━━━━ 37/82 [fonttools]
#       Successfully uninstalled coverage-7.8.0━━━━━━━━━━━━━━━━━ 37/82 [fonttools]
#   Attempting uninstall: click╺━━━━━━━━━━━━━━━━━━━ 42/82 [coverage]
#     Found existing installation: click 8.1.8━━━━━━━━━━━━━━━━━━ 42/82 [coverage]
#     Uninstalling click-8.1.8:╺━━━━━━━━━━━━━━━━━━━ 42/82 [coverage]
#       Successfully uninstalled click-8.1.8m━━━━━━━━━━━━━━━━━━━ 42/82 [coverage]
#   Attempting uninstall: charset-normalizerm━━━━━━━━━━━━━━━━━━━ 42/82 [coverage]
#     Found existing installation: charset-normalizer 3.4.2━━━━━ 42/82 [coverage]
#     Uninstalling charset-normalizer-3.4.2:m━━━━━━━━━━━━━━━━━━━ 42/82 [coverage]
#       Successfully uninstalled charset-normalizer-3.4.2━━━━━━━ 42/82 [coverage]
#   Attempting uninstall: certifi0m╺━━━━━━━━━━━━━━━━━━━ 42/82 [coverage]
#     Found existing installation: certifi 2025.4.26━━━━━━━━━━━━ 42/82 [coverage]
#     Uninstalling certifi-2025.4.26:━━━━━━━━━━━━━━━━━━━ 42/82 [coverage]
#       Successfully uninstalled certifi-2025.4.26━━━━━━━━━━━━━━ 42/82 [coverage]
#   Attempting uninstall: backports-datetime-fromisoformat━━━━━━ 42/82 [coverage]
#     Found existing installation: backports-datetime-fromisoformat 2.0.3m42/82 [coverage]
#     Uninstalling backports-datetime-fromisoformat-2.0.3:━━━━━━ 42/82 [coverage]
#       Successfully uninstalled backports-datetime-fromisoformat-2.0.332m42/82 [coverage]
#   Attempting uninstall: annotated-types━━━━━━━━━━━━━━━━━━━ 42/82 [coverage]
#     Found existing installation: annotated-types 0.7.0━━━━━━━━ 42/82 [coverage]
#     Uninstalling annotated-types-0.7.0:━━━━━━━━━━━━━━━━━━━ 42/82 [coverage]
#       Successfully uninstalled annotated-types-0.7.0━━━━━━━━━━ 42/82 [coverage]
#   Attempting uninstall: scipy╺━━━━━━━━━━━━━━━━━━━ 42/82 [coverage]
#     Found existing installation: scipy 1.15.2━━━━━━━━━━━━━━━━━ 42/82 [coverage]
#     Uninstalling scipy-1.15.2:━╺━━━━━━━━━━━━━━━━ 48/82 [scipy]
#       Successfully uninstalled scipy-1.15.290m━━━━━━━━━━━━━━━━ 48/82 [scipy]
#   Attempting uninstall: ruamel-yaml╺━━━━━━━━━━━━━━━━ 48/82 [scipy]
#     Found existing installation: ruamel.yaml 0.18.10━━━━━━━━━━ 48/82 [scipy]
#     Uninstalling ruamel.yaml-0.18.10:━━━━━━━━━━━━━━━━ 48/82 [scipy]
#       Successfully uninstalled ruamel.yaml-0.18.10━━━━━━━━━━━━ 48/82 [scipy]
#   Attempting uninstall: requests╺━━━━━━━━━━━━━━━━ 48/82 [scipy]
#     Found existing installation: requests 2.32.3━━━━━━━━━━━━━━ 48/82 [scipy]
#     Uninstalling requests-2.32.3:90m╺━━━━━━━━━━━━━━━━ 48/82 [scipy]
#       Successfully uninstalled requests-2.32.3━━━━━━━━━━━━━━━━ 48/82 [scipy]
#   Attempting uninstall: python-dateutil0m━━━━━━━━━━━━━━━━ 48/82 [scipy]
#     Found existing installation: python-dateutil 2.9.0.post0━━ 48/82 [scipy]
#     Uninstalling python-dateutil-2.9.0.post0:m━━━━━━━━━━━━━━━━ 48/82 [scipy]
#       Successfully uninstalled python-dateutil-2.9.0.post0━━━━ 48/82 [scipy]
#   Attempting uninstall: pytestm╺━━━━━━━━━━━━━━━━ 48/82 [scipy]
#     Found existing installation: pytest 8.3.5m━━━━━━━━━━━━━━━━ 48/82 [scipy]
#     Uninstalling pytest-8.3.5:m╺━━━━━━━━━━━━━━━━ 48/82 [scipy]
#       Successfully uninstalled pytest-8.3.5━━━━━━━━━━━━━━ 52/82 [pytest]
#   Attempting uninstall: pydantic-core╺━━━━━━━━━━━━━━ 52/82 [pytest]
#     Found existing installation: pydantic_core 2.23.4━━━━━━━━━ 52/82 [pytest]
#     Uninstalling pydantic_core-2.23.4:╺━━━━━━━━━━━━━━ 52/82 [pytest]
#       Successfully uninstalled pydantic_core-2.23.4━━━━━━━━━━━ 52/82 [pytest]
#   Attempting uninstall: pbr━━╺━━━━━━━━━━━━━━ 52/82 [pytest]
#     Found existing installation: pbr 6.1.1m━━━━━━━━━━━━━━ 52/82 [pytest]
#     Uninstalling pbr-6.1.1:━━╺━━━━━━━━━━━━━━ 52/82 [pytest]
#       Successfully uninstalled pbr-6.1.1━━━━━━━━━━━━━━ 52/82 [pytest]
#   Attempting uninstall: nltk━╺━━━━━━━━━━━━━━ 52/82 [pytest]
#     Found existing installation: nltk 3.9.1━━━━━━━━━━━━━━ 52/82 [pytest]
#     Uninstalling nltk-3.9.1:━╺━━━━━━━━━━━━━━ 52/82 [pytest]
#       Successfully uninstalled nltk-3.9.10m━━━━━━━━━━━━━━ 52/82 [pytest]
#   Attempting uninstall: marshmallow╸━━━━━━━━━━━━━ 55/82 [nltk]
#     Found existing installation: marshmallow 4.0.0━━━━━━━━━━━━ 55/82 [nltk]
#     Uninstalling marshmallow-4.0.0:╸━━━━━━━━━━━━━ 55/82 [nltk]
#       Successfully uninstalled marshmallow-4.0.0m━━━━━━━━━━━━━ 55/82 [nltk]
#   Attempting uninstall: markdown-it-pym╸━━━━━━━━━━━━━ 55/82 [nltk]
#     Found existing installation: markdown-it-py 3.0.0━━━━━━━━━ 55/82 [nltk]
#     Uninstalling markdown-it-py-3.0.0:m╸━━━━━━━━━━━━━ 55/82 [nltk]
#       Successfully uninstalled markdown-it-py-3.0.0━━━━━━━━━━━ 55/82 [nltk]
#   Attempting uninstall: jinja2━━━━━╸━━━━━━━━━━━━ 57/82 [markdown-it-py]
#     Found existing installation: Jinja2 3.1.6━━━━━━━━━━━━ 57/82 [markdown-it-py]
#     Uninstalling Jinja2-3.1.6:━╸━━━━━━━━━━━━ 57/82 [markdown-it-py]
#       Successfully uninstalled Jinja2-3.1.60m━━━━━━━━━━━━ 57/82 [markdown-it-py]
#   Attempting uninstall: httpcore╸━━━━━━━━━━━━ 57/82 [markdown-it-py]
#     Found existing installation: httpcore 1.0.990m━━━━━━━━━━━━ 57/82 [markdown-it-py]
#     Uninstalling httpcore-1.0.9:╸━━━━━━━━━━━━ 57/82 [markdown-it-py]
#       Successfully uninstalled httpcore-1.0.9━━━━━━━━━━━━ 57/82 [markdown-it-py]
#   Attempting uninstall: dparse━╸━━━━━━━━━━━━ 57/82 [markdown-it-py]
#     Found existing installation: dparse 0.6.4━━━━━━━━━━━━ 57/82 [markdown-it-py]
#     Uninstalling dparse-0.6.4:━╸━━━━━━━━━━━━ 57/82 [markdown-it-py]
#       Successfully uninstalled dparse-0.6.40m━━━━━━━━━━━━ 57/82 [markdown-it-py]
#   Attempting uninstall: contourpy0m╸━━━━━━━━━━━━ 57/82 [markdown-it-py]
#     Found existing installation: contourpy 1.3.20m━━━━━━━━━━━━ 57/82 [markdown-it-py]
#     Uninstalling contourpy-1.3.2:0m╸━━━━━━━━━━━━ 57/82 [markdown-it-py]
#       Successfully uninstalled contourpy-1.3.2━━━━━━━━━━━━ 57/82 [markdown-it-py]
#   Attempting uninstall: cffi━━━╸━━━━━━━━━━━━ 57/82 [markdown-it-py]
#     Found existing installation: cffi 1.17.1m━━━━━━━━━━━━ 57/82 [markdown-it-py]
#     Uninstalling cffi-1.17.1:━━╸━━━━━━━━━━━━ 57/82 [markdown-it-py]
#       Successfully uninstalled cffi-1.17.1╺━━━━━━━━━ 62/82 [cffi]it-py]
#   Attempting uninstall: astroid━━━╺━━━━━━━━━ 62/82 [cffi]
#     Found existing installation: astroid 3.3.90m━━━━━━━━━ 62/82 [cffi]
#     Uninstalling astroid-3.3.9:━━━╺━━━━━━━━━ 62/82 [cffi]
#       Successfully uninstalled astroid-3.3.9━━━━━━━━━ 62/82 [cffi]
#   Attempting uninstall: anyio━━━━━━━━━╸━━━━━━━━━ 63/82 [astroid]
#     Found existing installation: anyio 4.9.0━━━━━━━━━ 63/82 [astroid]
#     Uninstalling anyio-4.9.0:━━━━━╸━━━━━━━━━ 63/82 [astroid]
#       Successfully uninstalled anyio-4.9.0m╸━━━━━━━━━ 63/82 [astroid]
#   Attempting uninstall: stevedore━╸━━━━━━━━━ 63/82 [astroid]
#     Found existing installation: stevedore 5.4.1━━━━━━━━━ 63/82 [astroid]
#     Uninstalling stevedore-5.4.1:━╸━━━━━━━━━ 63/82 [astroid]
#       Successfully uninstalled stevedore-5.4.10m━━━━━━━━━ 63/82 [astroid]
#   Attempting uninstall: rich━━━━━━╸━━━━━━━━━ 63/82 [astroid]
#     Found existing installation: rich 14.0.0━━━━━━━━━ 63/82 [astroid]
#     Uninstalling rich-14.0.0:━━━━━╸━━━━━━━━━ 63/82 [astroid]
#       Successfully uninstalled rich-14.0.0m╸━━━━━━━━━ 63/82 [astroid]
#   Attempting uninstall: pytest-cov━━━━━━╺━━━━━━━ 66/82 [rich]
#     Found existing installation: pytest-cov 6.1.1m━━━━━━━ 66/82 [rich]
#     Uninstalling pytest-cov-6.1.1:━━╺━━━━━━━ 66/82 [rich]
#       Successfully uninstalled pytest-cov-6.1.1━━━━━━━ 66/82 [rich]
#   Attempting uninstall: pylint━━━━━━╺━━━━━━━ 66/82 [rich]
#     Found existing installation: pylint 3.3.7╺━━━━━━━ 66/82 [rich]
#     Uninstalling pylint-3.3.7:━━━━━━╺━━━━━━━ 66/82 [rich]
#       Successfully uninstalled pylint-3.3.70m╺━━━━━━━ 66/82 [rich]
#   Attempting uninstall: pydantic━━━━━━━━━╺━━━━━━ 68/82 [pylint]
#     Found existing installation: pydantic 2.9.2━━━━━━ 68/82 [pylint]
#     Uninstalling pydantic-2.9.2:━━━━━━━━━╸━━━━━━ 69/82 [pydantic]
#       Successfully uninstalled pydantic-2.9.2m╸━━━━━━ 69/82 [pydantic]
#   Attempting uninstall: pandas━━━━━━━╸━━━━━━ 69/82 [pydantic]
#     Found existing installation: pandas 2.2.3m╸━━━━━━ 69/82 [pydantic]
#     Uninstalling pandas-2.2.3:━━━━━━━━━━━━╺━━━━━ 70/82 [pandas]
#       Successfully uninstalled pandas-2.2.3╺━━━━━ 70/82 [pandas]
#   Attempting uninstall: matplotlib━━━━━━━━╺━━━━━ 70/82 [pandas]
#     Found existing installation: matplotlib 3.10.10m━━━━━ 70/82 [pandas]
#     Uninstalling matplotlib-3.10.1:━━━╺━━━━━ 70/82 [pandas]
#       Successfully uninstalled matplotlib-3.10.1━━━━━ 70/82 [pandas]
#   Attempting uninstall: httpx━━━━━━━━━━━━━╸━━━━━ 71/82 [matplotlib]
#     Found existing installation: httpx 0.28.11m╸━━━━━ 71/82 [matplotlib]
#     Uninstalling httpx-0.28.1:━━━━━━━━╸━━━━━ 71/82 [matplotlib]
#       Successfully uninstalled httpx-0.28.1╸━━━━━ 71/82 [matplotlib]
#   Attempting uninstall: cryptography━━╸━━━━━ 71/82 [matplotlib]
#     Found existing installation: cryptography 44.0.3━━━━━ 71/82 [matplotlib]
#     Uninstalling cryptography-44.0.3:━╸━━━━━ 71/82 [matplotlib]
#       Successfully uninstalled cryptography-44.0.30m━━━━━ 71/82 [matplotlib]
#   Attempting uninstall: typer━━━━━━━━━━━━━━╸━━━━ 73/82 [cryptography]
#     Found existing installation: typer 0.15.391m╸━━━━ 73/82 [cryptography]
#     Uninstalling typer-0.15.3:━━━━━━━━━╸━━━━ 73/82 [cryptography]
#       Successfully uninstalled typer-0.15.3╸━━━━ 73/82 [cryptography]
#   Attempting uninstall: safety-schemas━╸━━━━ 73/82 [cryptography]
#     Found existing installation: safety-schemas 0.0.14━━━━ 73/82 [cryptography]
#     Uninstalling safety-schemas-0.0.14:╸━━━━ 73/82 [cryptography]
#       Successfully uninstalled safety-schemas-0.0.14m━━━━ 73/82 [cryptography]
#   Attempting uninstall: pandas_datareader0m╸━━━━ 73/82 [cryptography]
#     Found existing installation: pandas-datareader 0.10.0m━━━━ 73/82 [cryptography]
#     Uninstalling pandas-datareader-0.10.0:m╸━━━━ 73/82 [cryptography]
#       Successfully uninstalled pandas-datareader-0.10.090m━━━━ 73/82 [cryptography]
#   Attempting uninstall: bandit━━━━━━━━━━━━━━━╺━━ 76/82 [pandas_datareader]
#     Found existing installation: bandit 1.8.3╺━━ 76/82 [pandas_datareader]
#     Uninstalling bandit-1.8.3:━━━━━━━━━━━╺━━ 76/82 [pandas_datareader]
#       Successfully uninstalled bandit-1.8.30m╺━━ 76/82 [pandas_datareader]
#   Attempting uninstall: authlib━━━━━━━━━━╺━━ 76/82 [pandas_datareader]
#     Found existing installation: Authlib 1.5.2╺━━ 76/82 [pandas_datareader]
#     Uninstalling Authlib-1.5.2:━━━━━━━━━━╺━━ 76/82 [pandas_datareader]
#       Successfully uninstalled Authlib-1.5.2m╺━━ 76/82 [pandas_datareader]
#   Attempting uninstall: safety━━━━━━━━━━━━━━━━╺━ 78/82 [authlib]eader]
#     Found existing installation: safety 3.4.0m╺━ 78/82 [authlib]
#     Uninstalling safety-3.4.0:━━━━━━━━━━━━╺━ 78/82 [authlib]
#       Successfully uninstalled safety-3.4.0╺━ 78/82 [authlib]
#   Attempting uninstall: coinmetrics-api-client╸━ 79/82 [safety]
#     Found existing installation: coinmetrics-api-client 2025.5.6.1379/82 [safety]
#     Uninstalling coinmetrics-api-client-2025.5.6.13:━ 79/82 [safety]
#       Successfully uninstalled coinmetrics-api-client-2025.5.6.13m 79/82 [safety]
#   Attempting uninstall: hypertrial━━━━━━━━╸━ 79/82 [safety]
#     Found existing installation: hypertrial 0.1.14m╸━ 79/82 [safety]
#     Uninstalling hypertrial-0.1.14:━━━━━━━╸━ 79/82 [safety]
#       Successfully uninstalled hypertrial-0.1.1491m╸━ 79/82 [safety]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82/82 [hypertrial]m [safety]
# Successfully installed MarkupSafe-3.0.2 PyYAML-6.0.2 annotated-types-0.7.0 anyio-4.9.0 astroid-3.3.9 authlib-1.5.2 backports-datetime-fromisoformat-2.0.3 bandit-1.8.3 certifi-2025.4.26 cffi-1.17.1 charset-normalizer-3.4.2 click-8.1.8 coinmetrics-api-client-2025.5.6.13 contourpy-1.3.2 coverage-7.8.0 cryptography-44.0.3 cycler-0.12.1 dill-0.4.0 dparse-0.6.4 exceptiongroup-1.2.2 filelock-3.16.1 fonttools-4.57.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 hypertrial-0.1.14 idna-3.10 iniconfig-2.1.0 isort-6.0.1 jinja2-3.1.6 joblib-1.5.0 kiwisolver-1.4.8 lxml-5.4.0 markdown-it-py-3.0.0 marshmallow-4.0.0 matplotlib-3.10.1 mccabe-0.7.0 mdurl-0.1.2 nltk-3.9.1 numpy-2.2.5 orjson-3.10.18 packaging-25.0 pandas-2.2.3 pandas_datareader-0.10.0 pbr-6.1.1 pillow-11.2.1 platformdirs-4.3.7 pluggy-1.5.0 polars-1.29.0 psutil-6.1.1 pycparser-2.22 pydantic-2.9.2 pydantic-core-2.23.4 pygments-2.19.1 pylint-3.3.7 pyparsing-3.2.3 pytest-8.3.5 pytest-cov-6.1.1 python-dateutil-2.9.0.post0 pytz-2025.2 regex-2024.11.6 requests-2.32.3 rich-14.0.0 ruamel-yaml-0.18.10 ruamel.yaml.clib-0.2.12 safety-3.4.0 safety-schemas-0.0.14 scipy-1.15.2 setuptools-80.3.1 shellingham-1.5.4 six-1.17.0 sniffio-1.3.1 stevedore-5.4.1 tenacity-9.1.2 tomli-2.2.1 tomlkit-0.13.2 tqdm-4.67.1 typer-0.15.3 typing-extensions-4.13.2 tzdata-2025.2 urllib3-2.4.0 websocket-client-1.8.0

# %% [markdown]
# ## 🔍 Overview
#
# In this tutorial, we provide a helper function to run your strategy code from within the notebook.
# You will see:
# - A function that saves your strategy to a temporary `.py` file.
# - The execution of the strategy using the Hypertrial CLI.
# - An optional cleanup step to remove the temporary file after execution.

# %%
def run_strategy_from_notebook(strategy_code: str, filename: str = "temp_strategy.py", cleanup: bool = False):
    """
    Save strategy code to a .py file and run it with core.main using --strategy-file.
    
    Args:
        strategy_code (str): The full strategy code as a string
        filename (str): The .py filename to save
        cleanup (bool): If True, deletes the file after running
    """
    import os

    # Save code to .py file
    with open(filename, "w") as f:
        f.write(strategy_code)
    print(f"✅ Saved strategy to {filename}")

    # Run the strategy using Hypertrial CLI
    print("🚀 Running strategy...")
    exit_code = os.system(f"python3 -m core.main --strategy-file {filename} --standalone")

    # Optional cleanup
    if cleanup:
        os.remove(filename)
        print(f"🧹 Deleted {filename} after execution.")

    # Return exit code in case you want to handle it
    return exit_code

# %% [markdown]
# ## 🔧 Next Steps
#
# 1. **Insert Your Strategy:**
#    Paste your strategy code in the multi-line string named `model_code`.
#
# 2. **Validate Your Submission:**
#    Run the entire notebook to ensure that your strategy is tested correctly.
#
# 3. **Submission Guidelines:**
#    If you see "✅ Strategy passed all validation checks." that means you are ready to submit your code on Hypertrial.
#
# 4. **Troubleshooting:**
#    If you encounter any issues during execution, verify that all required dependencies are installed and that your Python environment is correctly configured. Or it may mean that your model's logic does not meet the criteria. We suggest going back to tutorial 3 and running your own set of tests to ensure the model is behaving as expected.

# %%
model_code = '''
import pandas as pd 
import numpy as np
from typing import Dict, Any
from core.config import BACKTEST_START, BACKTEST_END, MIN_WEIGHT
from core.strategies import register_strategy

def construct_features(df: pd.DataFrame) -> pd.DataFrame:
    """
    Construct technical indicators used for the strategy.
    Uses only past data for calculations to avoid look-ahead bias.
    
    Args:
        df: DataFrame with price data
        
    Returns:
        DataFrame with added technical indicators
    """
    df = df.copy()
    # Shift the btc_close column by one to use only past data for our calculations
    past_close = df['btc_close'].shift(1)
    # Calculate 200-day moving average
    df['ma200'] = past_close.rolling(window=200, min_periods=1).mean()
    # Calculate 200-day standard deviation
    df['std200'] = past_close.rolling(window=200, min_periods=1).std()
    return df

# Example Ethereum wallet address - replace with real one for actual submissions
ETH_WALLET_ADDRESS = "0x71C7656EC7ab88b098defB751B7401B5f6d8976F"

@register_strategy(ETH_WALLET_ADDRESS)
def compute_weights(df: pd.DataFrame) -> pd.Series:
    """
    Computes daily DCA weights with a 200-day moving average strategy.
    Increases weight on days when price is below MA, redistributing from future days.
    
    Strategy logic:
    1. Start with uniform weights across each market cycle
    2. For days when price < 200MA, boost weight proportional to distance below MA
    3. Redistribute the excess weight from future days within a rebalance window
    4. Maintain minimum weight constraints for all days
    
    Args:
        df: DataFrame with BTC price data
        
    Returns:
        Series of daily investment weights, summing to 1.0 per market cycle
    """
    # Strategy parameters
    REBALANCE_WINDOW = 365 * 2  # Redistribute weight from up to 2 years ahead
    ALPHA = 1.25  # Multiplier for how much to boost weight based on z-score
    
    df_work = df.copy()
    df_work = construct_features(df)
    
    # Filter to backtest period only
    df_backtest = df_work.loc[BACKTEST_START:BACKTEST_END]
    weights = pd.Series(index=df_backtest.index, dtype=float)
    
    # Group by 4-year market cycles
    start_year = pd.to_datetime(BACKTEST_START).year
    cycle_labels = df_backtest.index.to_series().apply(lambda dt: (dt.year - start_year) // 4)
    
    # Process each market cycle separately to maintain weight sum = 1.0 per cycle
    for cycle, group in df_backtest.groupby(cycle_labels):
        N = len(group)
        base_weight = 1.0 / N  # Start with uniform weight distribution
        temp_weights = np.full(N, base_weight)
        strategy_active = True  # Flag to stop adjustments if constraints can't be met
        
        # Process each day in the cycle
        for i in range(N):
            if not strategy_active:
                break
            
            price = group['btc_close'].iloc[i]
            ma200 = group['ma200'].iloc[i]
            std200 = group['std200'].iloc[i]
            
            # Skip days with insufficient history
            if pd.isna(ma200) or pd.isna(std200) or std200 <= 0:
                continue
            
            # Apply weight boost when price is below MA
            if price < ma200:
                # Calculate z-score (standard deviations below MA)
                z = (ma200 - price) / std200
                boost_multiplier = 1 + ALPHA * z
                current_weight = temp_weights[i]
                boosted_weight = current_weight * boost_multiplier
                excess = boosted_weight - current_weight
                
                # Determine which future days to redistribute from
                start_redistribution = max(N - REBALANCE_WINDOW, i + 1)
                if start_redistribution >= N:
                    continue  # No future days to redistribute from
                
                redistribution_idx = np.arange(start_redistribution, N)
                if len(redistribution_idx) == 0:
                    continue
                    
                # Calculate reduction per future day
                reduction = excess / len(redistribution_idx)
                projected = temp_weights[redistribution_idx] - reduction
                
                # Only apply changes if minimum weight constraint is satisfied
                if np.all(projected >= MIN_WEIGHT):
                    temp_weights[i] = boosted_weight
                    temp_weights[redistribution_idx] -= reduction
                else:
                    # Stop strategy adjustments if constraints can't be met
                    strategy_active = False
        
        # Assign weights back to the original index
        weights.loc[group.index] = temp_weights
    
    return weights
'''

# Run it
run_strategy_from_notebook(model_code, filename="dynamic_dca_200ma.py", cleanup=False)
# Out:
# ✅ Saved strategy to dynamic_dca_200ma.py
# 🚀 Running strategy...
# /Users/mashkani/miniconda3/envs/stacking-sats-env/lib/python3.10/runpy.py:126: RuntimeWarning: 'core.main' found in sys.modules after import of package 'core', but prior to execution of 'core.main'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# INFO:root:Loading BTC data from core/data/btc_price_data.csv
# INFO:root:Loaded 5381 records from 2010-07-18 00:00:00 to 2025-04-10 00:00:00
# INFO:core.security.utils:Running Bandit security analysis on /Users/mashkani/Documents/hypertrial/Stacking Sats Challenge/Tutorials/dynamic_dca_200ma.py
# INFO:core.security.utils:Bandit security scan: 0 issues found (High: 0, Medium: 0, Low: 0)
# INFO:core.security.utils:Strategy file /Users/mashkani/Documents/hypertrial/Stacking Sats Challenge/Tutorials/dynamic_dca_200ma.py passed security validation
# INFO:core.strategy_loader:Loading strategy from file: /Users/mashkani/Documents/hypertrial/Stacking Sats Challenge/Tutorials/dynamic_dca_200ma.py
# INFO:core.strategies:Registered strategy: 0x71C7656EC7ab88b098defB751B7401B5f6d8976F
# INFO:core.strategy_loader:Successfully loaded strategy '0x71C7656EC7ab88b098defB751B7401B5f6d8976F' from file: /Users/mashkani/Documents/hypertrial/Stacking Sats Challenge/Tutorials/dynamic_dca_200ma.py
# INFO:core.strategy_processor:Validating strategy '0x71C7656EC7ab88b098defB751B7401B5f6d8976F' against submission criteria...
# INFO:core.spd:Computing SPD metrics for '0x71C7656EC7ab88b098defB751B7401B5f6d8976F' from 2013-01-01 to 2024-12-31
# Weight sums by cycle (should be close to 1.0):
# Cycle 2013–2016: 1.0000
# Cycle 2017–2020: 1.0000
# Cycle 2021–2024: 1.0000
#
# SPD Metrics for 0x71C7656EC7ab88b098defB751B7401B5f6d8976F:
# Dynamic SPD:
#   min: 3485.52
#   max: 596340.41
#   mean: 208274.07
#   median: 24996.29
#
# ✅ Strategy passed all validation checks.
# 0
